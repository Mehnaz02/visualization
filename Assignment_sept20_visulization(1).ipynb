# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Python Matplotlib: Plot Sales for various markets for years 2012 to 2015 using SubPlots with n columns and combine value of regions
#
# Problem Statement
#
# Create a subplots as show in fig with given years and sales data
#
# Years 2012 2013 2014 2015
#
# Africa 127187.27 144480.7 229068.79 283036.44
#
# USCA 492756.6 486629.3 627634.98 757108.13
#
# LATAM 385098.15 464733.29 608140.77 706632.93
#
# Asia Pacific 713658.22 863983.97 1092231.65 1372784.4
#
# Europe 540750.63 717611.4 848670.24 1180303.95
#
# 1) Create subplots of 4 columns
#
# 2) Show line graph for Europe with color red and title Sales in Europe
#
# 3) Show bar for USCA with title Sales in USCA
#
# 4) Show scatter plot for Africa
#
# 5) Combine data for Asia Pacific and LATM and set title "Sales in Asia Pacific and LATAM"
#
# 6) Set color of ASIA bar to royalblue and LATAM bar to sea green and set Legend for them
#
# 7) Set width of ASIA bar and LARAM bar to 0.5
#
# 8) Set figure size in inches to 20.5 and 5.5

# %%
df1=pd.DataFrame({'Year':[2012,2013,2014,2015],
                  'Africa':[127187.27,144480.7,229068.79,283036.44],
                  'USCA':[492756.6,486629.3,627634.98,757108.13],
                  'LATAM':[385098.15,464733.29,608140.77,706632.93],
                  'Asia Pacific':[713658.22,863983.97,1092231.65,1372784.4],
                  'Europe':[540750.63,717611.4,848670.24,1180303.95]
                 })

# %%
df1
# Out:
#    Year     Africa       USCA      LATAM  Asia Pacific      Europe
# 0  2012  127187.27  492756.60  385098.15     713658.22   540750.63
# 1  2013  144480.70  486629.30  464733.29     863983.97   717611.40
# 2  2014  229068.79  627634.98  608140.77    1092231.65   848670.24
# 3  2015  283036.44  757108.13  706632.93    1372784.40  1180303.95

# %%
import matplotlib.pyplot as plt
import seaborn as sns
axis=plt.subplots(2,2,figsize=(20.5,5.5))

plt.subplot(2,2,1)
plt.plot(df1['Europe'],color='r')
plt.title('Sales in Europe')


plt.subplot(2,2,2)
sns.barplot(x=x,y=y,data=df1)
plt.title('Sales in USCA')

plt.subplot(2,2,3)
sns.scatterplot(df1['Africa'])


plt.subplot(2,2,4)

plt.plot(df1['Asia Pacific'],c='royalblue')
plt.plot(df1['LATAM'],c='green')        
plt.title('Sales in Asia Pacific and LATAM')
plt.legend('AL')
